# %%
import pandas as pd

# %%
# !pip install lightgbm
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 921 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

df = pd.read_csv('/project_data/data_asset/Customer Retail Data.csv')
df.head()
# Out:
#         CustomerID  Birth_Date    Age Sex  Customer_Years  \
# 0  001300000082xer  1979-06-21  120.0   f              15
# 1  0013000000830UR  1956-12-11   51.0   f              12
# 2  001300000082yh3  1992-08-31   63.0   f               8
# 3  00130000008300v  1982-06-27  135.0   m              15
# 4  0013000000834Bs  1986-01-07   37.0   m              15
#
#           Product_Group  Total_Store Visits Marketing_Channel Marital Status  \
# 0  Middle Price Segment                 144            Letter         single
# 1        Good and cheap                 381            Letter        Married
# 2                 Sales                 190            Letter            NaN
# 3   Upper Price Segment                 138             Email         single
# 4   Upper Price Segment                  67             Email         single
#
#    Children      Payment Region     Area  Revenue_Total  Mean_Purchase_Amount  \
# ...

# %%
df.describe()
# Out:
#                Age  Customer_Years  Total_Store Visits     Children  \
# count  1886.000000     1892.000000         1892.000000  1892.000000
# mean     34.199364       13.486258           95.987844     0.518499
# std      11.457337        2.883297          104.577093     0.499790
# min      21.000000        8.000000            0.000000     0.000000
# 25%      27.000000       12.000000           19.000000     0.000000
# 50%      30.000000       12.000000           55.000000     1.000000
# 75%      40.000000       15.000000          139.000000     1.000000
# max     135.000000       21.000000          476.000000     1.000000
#
#        Revenue_Total  Mean_Purchase_Amount  Highest_Articel_Revenue
# count    1854.000000           1289.000000              1868.000000
# mean    17083.122977             64.082196               200.757693
# std      7974.046264             68.357231               155.572679
# min      9000.000000              5.990000                 2.000000
# ...

# %%
import numpy
